# %%
# %load_ext autoreload

# %%
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from tqdm import tqdm

from src.utils import get_trajectories_df, get_user_ids, get_activities_df, get_labeled_ids

# %%
# Progress bar using tqdm looping through a list
for i in tqdm(range(10000000)):
    pass
# Out:
# 100%|██████████| 10000000/10000000 [00:00<00:00, 10165358.08it/s]

# %%
print(get_trajectories_df("128"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/notebooks/data.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/notebooks/data.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> get_trajectories_df("128")
#
# File ~/Desktop/ntnu/tdt4225-mysql/src/utils/data.py:131, in get_trajectories_df(user_id)
#     129     # Add trajectory to trajectories dataframe
#     130     if trajectory.shape[0] <= 2500:
# --> 131         trajectories = pd.concat([trajectories, trajectory])
#     133 print("hei")
#     135 # Create an empty list to store selected trajectories
#
# File ~/anaconda3/envs/mysql/lib/python3.11/site-packages/pandas/core/reshape/concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
# ...

# %%
user_ids = get_labeled_ids()
data_to_insert = []

pbar = tqdm(user_ids)
for user in pbar:
    pbar.set_description("Processing TrackPoints of user %s" % user)
    trajectories_df = get_trajectories_df(user)
    # if trajectories_df.shape[0] > 1500:
    #     continue
    pbar.set_description("Appending TrackPoints of user %s" % user)
    # for _, row in trajectories_df.iterrows():
    #     data_to_insert.append(
    #         (
    #             row["activity_id"],
    #             row["latitude"],
    #             row["longitude"],
    #             row["altitude"],
    #             row["date_time"],
    #         )
    #     )
# Out:
# Processing TrackPoints of user 062:  13%|█▎        | 9/69 [00:32<03:33,  3.57s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/notebooks/data.ipynb Cell 4 line 7
#       <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> for user in pbar:
#       <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     pbar.set_description("Processing TrackPoints of user %s" % user)
# ----> <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     trajectories_df = get_trajectories_df(user)
# ...

# %%
activities = get_activities_df("104")
activities
# Out:
#        start_date_time       end_date_time transportation_mode user_id  \
# 0  2007-11-30 09:59:00 2007-11-30 10:38:00                 bus     104
# 1  2007-11-30 12:40:00 2007-11-30 13:18:00                 bus     104
# 2  2007-12-02 12:27:00 2007-12-02 12:57:00                 bus     104
# 3  2007-12-02 13:00:00 2007-12-02 13:25:00                 bus     104
# 4  2007-12-04 07:45:00 2007-12-04 08:30:00                 car     104
# ..                 ...                 ...                 ...     ...
# 83 2008-12-27 03:47:00 2008-12-27 04:11:00                 bus     104
# 84 2008-12-27 10:19:00 2008-12-27 11:40:00                 bus     104
# 85 2008-12-30 03:03:00 2008-12-30 03:22:00                 bus     104
# 86 2008-12-30 05:00:00 2008-12-30 05:17:00                 bus     104
# 87 2008-12-31 13:59:00 2008-12-31 14:55:00                taxi     104
#
#                 id
# 0   20071130095900
# 1   20071130124000
# 2   20071202122700
# 3   20071202130000
# ...

# %%
trajectories = get_trajectories_df("104")
trajectories
# Out:
# /Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/src/utils/data_load.py:94: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#       latitude   longitude altitude           date_time     activity_id
# 0    39.966107  116.340690        0 2008-01-01 09:42:31  20080101094000
# 1    39.966100  116.341192        0 2008-01-01 09:42:34  20080101094000
# 2    39.966090  116.341647        0 2008-01-01 09:42:37  20080101094000
# 3    39.966098  116.342063        0 2008-01-01 09:42:40  20080101094000
# 4    39.966103  116.342487        0 2008-01-01 09:42:43  20080101094000
# ..         ...         ...      ...                 ...             ...
# 317  39.917292  116.309435        0 2008-03-28 09:40:01  20080328084200
# ...
